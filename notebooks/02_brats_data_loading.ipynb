# %%
import os
import numpy as  np 
import nibabel as nb
import matplotlib.pyplot as plt

# %%
import nibabel as nib

file_path = "data/BraTS2020/BraTS20_Training_001/BraTS20_Training_001_flair.nii"

img = nib.load(file_path)
data = img.get_fdata()

print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\simi\AppData\Local\Programs\Python\Python312\Lib\site-packages\nibabel\loadsave.py:104, in load(filename, **kwargs)
#     103 try:
# --> 104     stat_result = os.stat(filename)
#     105 except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/BraTS2020/BraTS20_Training_001/BraTS20_Training_001_flair.nii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 import nibabel as nib
#       3 file_path = "data/BraTS2020/BraTS20_Training_001/BraTS20_Training_001_flair.nii"
# ----> 5 img = nib.load(file_path)
#       6 data = img.get_fdata()
#       8 print(data.shape)
#
# ...
