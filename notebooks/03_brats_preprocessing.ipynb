# %%
import sys
sys.path.append("..")

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

from data_preprocessing.crop_brain import crop_brain

# %%
import nibabel as nib

file_path = "../data/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_flair.nii"

img = nib.load(file_path)
data = img.get_fdata()

print("Original shape:", data.shape)
# Out:
# Original shape: (240, 240, 155)

# %%
cropped = crop_brain(data)

print("Cropped shape:", cropped.shape)
# Out:
# Cropped shape: (136, 172, 134)

# %%
slice_index = cropped.shape[2] // 2

plt.imshow(cropped[:, :, slice_index], cmap="gray")
plt.title("Cropped MRI Slice")
plt.axis("off")
plt.show()
